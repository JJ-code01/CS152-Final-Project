# %%
import librosa
import numpy as np
import soundfile as sf

# read file
file    = "Data/test.wav"
sig, fs = librosa.core.load(file)

l = sig.shape[0]
sig = sig[:int(l/10)]

# %%
# process
abs_spectrogram = np.abs(librosa.core.spectrum.stft(sig))

# %%
fig, ax = plt.subplots()
img = librosa.display.specshow(librosa.amplitude_to_db(abs_spectrogram,
                                                       ref=np.max),
                               y_axis='log', x_axis='time', ax=ax)
ax.set_title('Power spectrogram')
fig.colorbar(img, ax=ax, format="%+2.0f dB")

# %%
abs_spectrogram.shape
# Out:
# (1025, 130)

# %%
audio_signal = librosa.griffinlim(abs_spectrogram)

print(audio_signal, audio_signal.shape)

# write output
# sf.write('Data/test_out.wav', fs, np.array(audio_signal, dtype=np.int16))

sf.write('Data/test_out_short.wav', audio_signal, fs, 'PCM_24')
# Out:
# [-0.00922428 -0.01043329 -0.01703326 ...  0.05047528  0.08210868
#   0.08458346] (66048,)
